# %%
print('hello')
# Out:
# hello

# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\sskim\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install selenium #매크로
# Out:
# ...
#      ------------------------------------- 981.4/981.4 KB 15.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 139.0/139.0 KB 8.6 MB/s eta 0:00:00
# ...
#      ------------------------------------- 359.0/359.0 KB 21.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 61.2/61.2 KB ? eta 0:00:00
# ...
#      ---------------------------------------- 2.4/2.4 MB 21.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.8/55.8 KB ? eta 0:00:00
# ...
#      -------------------------------------- 160.2/160.2 KB 9.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 58.2/58.2 KB 3.0 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\sskim\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install --upgrade pip
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 19.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.4
#     Uninstalling pip-22.0.4:
#       Successfully uninstalled pip-22.0.4
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\sskim\\AppData\\Local\\Temp\\pip-uninstall-_vkfti8_\\pip.exe'
# Consider using the `--user` option or check the permissions.

# %%
print('hi')
# Out:
# hi

# %%
clear

# %%
from selenium import webdriver

# %%
driver =webdriver.Chrome() # 매크로

# %%
driver.get('https://tickets.interpark.com/goods/22004840')

# %%
#로그인, 스크롤, 속도 느림, 사람과 구분 쉽지않음
from selenium.webdriver.common.by import By
driver.find_element(By.XPATH,"""//*[@id="productMainBody"]/nav/div/div/ul/li[4]/a""").click() # 검사에서 필요한 글자 '기대평'  aclass 우클릭 후 copy xpass

# %%
source = driver.page_source
# Out:
# '<html lang="ko"><head><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/ec.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://js.appboycdn.com/web-sdk/3.2/appboy.min.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-4SKTL7E8Q8&amp;l=dataLayer&amp;cx=c"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5QCJFLB&amp;gtm_auth=&amp;gtm_preview=&amp;gtm_cookies_win=x"></script><script>\n      (function(w,d,s,l,i){w[l]=w[l]||[];\n        w[l].push({\'gtm.start\': new Date().getTime(),event:\'gtm.js\', });\n        var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';\n        j.async=true;j.src=\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl+\'&gtm_auth=&gtm_preview=&gtm_cookies_win=x\';\n        f.parentNode.inser
# ...

# %%
# !pip install bs4
from bs4 import BeautifulSoup
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# Using legacy 'setup.py install' for bs4, since package 'wheel' is not installed.
# ...
#   Running setup.py install for bs4: started
#   Running setup.py install for bs4: finished with status 'done'
# ...

# %%
source = driver.page_source 
html=(BeautifulSoup(source))
html
# Out:
# <html lang="ko"><head><script async="" src="https://www.google-analytics.com/plugins/ua/ec.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://js.appboycdn.com/web-sdk/3.2/appboy.min.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-4SKTL7E8Q8&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5QCJFLB&amp;gtm_auth=&amp;gtm_preview=&amp;gtm_cookies_win=x"></script><script>
#       (function(w,d,s,l,i){w[l]=w[l]||[];
#         w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js', });
#         var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#         j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl+'&gtm_auth=&gtm_preview=&gtm_cookies_win=x';
# ...
