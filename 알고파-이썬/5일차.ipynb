# %%
import pandas as pd

df = pd.read_csv("gapminder.tsv",sep='\t')
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
#csv 데이터가 ,로 구분 , tsv 탭으로 구분

df.head(n=10) # 앞부분만 표시
df.tail() #뒷부분만 표시
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape # (행,열)
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.dtypes # pandas에서 object = 문자열 //
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
# int : 정수
# float : 실수
# object : 문자열
# datetime : 날짜

#pandas에서 표: 데이터 프레임 // 열 : 시리즈
df['country'] # 열 1개에 접근
df[['country','year']] # 열 2개에 접근
# Out:
#           country  year
# 0     Afghanistan  1952
# 1     Afghanistan  1957
# 2     Afghanistan  1962
# 3     Afghanistan  1967
# 4     Afghanistan  1972
# ...           ...   ...
# 1699     Zimbabwe  1987
# 1700     Zimbabwe  1992
# 1701     Zimbabwe  1997
# 1702     Zimbabwe  2002
# 1703     Zimbabwe  2007
#
# [1704 rows x 2 columns]

# %%
# 행열

# loc : 이름로 접근
# iloc : 순서로 접근
df.loc[0] # 0이라고 적힌 행 1개
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.iloc[0] # 0번째 행
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.loc[[0,10,100,1000],['country','year']] # 0, 10, 100, 1000 이라 적힌행의 country, year 열
# Out:
#           country  year
# 0     Afghanistan  1952
# 10    Afghanistan  2002
# 100    Bangladesh  1972
# 1000     Mongolia  1972

# %%
df.iloc[[0,10,100,1000],[0,2]]
# Out:
#           country  year
# 0     Afghanistan  1952
# 10    Afghanistan  2002
# 100    Bangladesh  1972
# 1000     Mongolia  1972

# %%
df.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.loc[:,['year','country']] #  : =전부
# Out:
#       year      country
# 0     1952  Afghanistan
# 1     1957  Afghanistan
# 2     1962  Afghanistan
# 3     1967  Afghanistan
# 4     1972  Afghanistan
# ...    ...          ...
# 1699  1987     Zimbabwe
# 1700  1992     Zimbabwe
# 1701  1997     Zimbabwe
# 1702  2002     Zimbabwe
# 1703  2007     Zimbabwe
#
# [1704 rows x 2 columns]

# %%
df.iloc[:,:3]
# Out:
#           country continent  year
# 0     Afghanistan      Asia  1952
# 1     Afghanistan      Asia  1957
# 2     Afghanistan      Asia  1962
# 3     Afghanistan      Asia  1967
# 4     Afghanistan      Asia  1972
# ...           ...       ...   ...
# 1699     Zimbabwe    Africa  1987
# 1700     Zimbabwe    Africa  1992
# 1701     Zimbabwe    Africa  1997
# 1702     Zimbabwe    Africa  2002
# 1703     Zimbabwe    Africa  2007
#
# [1704 rows x 3 columns]

# %%
df.loc[10:12,['country','lifeExp']]
# Out:
#         country  lifeExp
# 10  Afghanistan   42.129
# 11  Afghanistan   43.828
# 12      Albania   55.230

# %%
a = df.groupby('year')
len(list(a))
# Out:
# 12

# %%
list(a)[0][1] #0은 1952, 1은 1952의 데이터 프레임
# Out:
#                  country continent  year  lifeExp       pop    gdpPercap
# 0            Afghanistan      Asia  1952   28.801   8425333   779.445314
# 12               Albania    Europe  1952   55.230   1282697  1601.056136
# 24               Algeria    Africa  1952   43.077   9279525  2449.008185
# 36                Angola    Africa  1952   30.015   4232095  3520.610273
# 48             Argentina  Americas  1952   62.485  17876956  5911.315053
# ...                  ...       ...   ...      ...       ...          ...
# 1644             Vietnam      Asia  1952   40.412  26246839   605.066492
# 1656  West Bank and Gaza      Asia  1952   43.160   1030585  1515.592329
# 1668         Yemen, Rep.      Asia  1952   32.548   4963829   781.717576
# 1680              Zambia    Africa  1952   42.038   2672000  1147.388831
# 1692            Zimbabwe    Africa  1952   48.451   3080907   406.884115
#
# [142 rows x 6 columns]

# %%
a = df.groupby('year')['lifeExp'].mean()
a
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
a.plot()

# %%
b=df.groupby(['year','continent'])['lifeExp'].mean() #년도별 대륙별 그룹바이
b
# Out:
# year  continent
# 1952  Africa       39.135500
#       Americas     53.279840
#       Asia         46.314394
#       Europe       64.408500
#       Oceania      69.255000
# 1957  Africa       41.266346
#       Americas     55.960280
#       Asia         49.318544
#       Europe       66.703067
#       Oceania      70.295000
# 1962  Africa       43.319442
#       Americas     58.398760
#       Asia         51.563223
#       Europe       68.539233
#       Oceania      71.085000
# 1967  Africa       45.334538
#       Americas     60.410920
#       Asia         54.663640
#       Europe       69.737600
#       Oceania      71.310000
# 1972  Africa       47.450942
#       Americas     62.394920
#       Asia         57.319269
#       Europe       70.775033
#       Oceania      71.910000
# 1977  Africa       49.580423
#       Americas     64.391560
#       Asia         59.610556
#       Europe       71.937767
#       Oceania      72.855000
# 1982  Africa       51.592865
# ...

# %%
df.groupby('continent')['country'].nunique() #중복없이 세기 count = 그냥 세기만함
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
df.groupby(['year','continent'])['lifeExp','gdpPercap'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
# ...

# %%
#시리즈, 데이터 프레임

a = pd.Series([50,100,150], index=['A','B','C'])
a
# Out:
# A     50
# B    100
# C    150
# dtype: int64

# %%
b=pd.DataFrame({
    '이름' : ['장원영','아이유','강동원'],
    '성별' : ['여자','여자','남자'],
    '나이':[19,31,40]
},index=['사람1','사람2','사람3'],columns=['성별','이름','나이'])
b
# Out:
#      성별   이름  나이
# 사람1  여자  장원영  19
# 사람2  여자  아이유  31
# 사람3  남자  강동원  40

# %%
b.index=['A','B','C']
b
# Out:
#    성별   이름  나이
# A  여자  장원영  19
# B  여자  아이유  31
# C  남자  강동원  40

# %%
b.columns
# Out:
# Index(['성별', '이름', '나이'], dtype='object')

# %%
year=df['year']
year
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
year.mean()
# Out:
# 1979.5

# %%
year.max()
# Out:
# 2007

# %%
year.min()
# Out:
# 1952

# %%
year.median()
# Out:
# 1979.5

# %%
year.std()
# Out:
# 17.265329508973615

# %%
year.drop_duplicates() #중복된 값 없애기
# Out:
# 0     1952
# 1     1957
# 2     1962
# 3     1967
# 4     1972
# 5     1977
# 6     1982
# 7     1987
# 8     1992
# 9     1997
# 10    2002
# 11    2007
# Name: year, dtype: int64

# %%
year.sort_values() #  매개변수에 ascending =False 내림차순
# Out:
# 1703    2007
# 491     2007
# 515     2007
# 527     2007
# 539     2007
#         ...
# 1116    1952
# 1128    1952
# 1140    1952
# 1152    1952
# 852     1952
# Name: year, Length: 1704, dtype: int64

# %%
year.describe()
# Out:
# count    1704.00000
# mean     1979.50000
# std        17.26533
# min      1952.00000
# 25%      1965.75000
# 50%      1979.50000
# 75%      1993.25000
# max      2007.00000
# Name: year, dtype: float64

# %%
year.isin([1952,2000]) # 구간 안에 있을 경우 True
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: year, Length: 1704, dtype: bool

# %%
year.append(a) # 시리즈끼리 합치기 가능
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1702    2002
# 1703    2007
# A         50
# B        100
# C        150
# Length: 1707, dtype: int64

# %%
year.sample(10) #랜덤으로 10개 추출
# Out:
# 553     1957
# 1236    1952
# 1044    1952
# 1598    1962
# 21      1997
# 773     1977
# 252     1952
# 524     1992
# 1385    1977
# 1694    1962
# Name: year, dtype: int64

# %%
year.to_frame() # 시리즈를 데이터프레임으로 변환
# Out:
#       year
# 0     1952
# 1     1957
# 2     1962
# 3     1967
# 4     1972
# ...    ...
# 1699  1987
# 1700  1992
# 1701  1997
# 1702  2002
# 1703  2007
#
# [1704 rows x 1 columns]

# %%
year+10000 # 모든값에 10000 더하기
# Out:
# 0       11952
# 1       11957
# 2       11962
# 3       11967
# 4       11972
#         ...
# 1699    11987
# 1700    11992
# 1701    11997
# 1702    12002
# 1703    12007
# Name: year, Length: 1704, dtype: int64

# %%
year*year #year 제곱
# Out:
# 0       3810304
# 1       3829849
# 2       3849444
# 3       3869089
# 4       3888784
#          ...
# 1699    3948169
# 1700    3968064
# 1701    3988009
# 1702    4008004
# 1703    4028049
# Name: year, Length: 1704, dtype: int64

# %%
a.index=[0,1,2]

# %%
year + a # 0 1 2 더 할 수 있는 것만 더하고 나머지는 NaN
# Out:
# 0       2002.0
# 1       2057.0
# 2       2112.0
# 3          NaN
# 4          NaN
#          ...
# 1699       NaN
# 1700       NaN
# 1701       NaN
# 1702       NaN
# 1703       NaN
# Length: 1704, dtype: float64

# %%
df = pd.read_csv('scientists.csv')
df
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
ages = df['Age']
ages[ages>ages.mean()] # 평균보다 큰 값 추출
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
ages>ages.mean()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool

# %%
df[df['Age']>df['Age'].mean()] #평균연령 이상 행 추출
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 448.0+ bytes

# %%
df['Born2']=pd.to_datetime(df['Born'], format = '%Y-%m-%d') # 형식을 알려줘야함
df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#        Born2
# 0 1920-07-25
# 1 1876-06-13
# 2 1820-05-12
# 3 1867-11-07
# 4 1907-05-27
# 5 1813-03-15
# 6 1912-06-23
# 7 1777-04-30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
#  5   Born2       8 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 512.0+ bytes

# %%
df['Died2']=pd.to_datetime(df['Died'], format = '%Y-%m-%d') # 형식을 알려줘야함
df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#        Born2      Died2
# 0 1920-07-25 1958-04-16
# 1 1876-06-13 1937-10-16
# 2 1820-05-12 1910-08-13
# 3 1867-11-07 1934-07-04
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07
# 7 1777-04-30 1855-02-23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
#  5   Born2       8 non-null      datetime64[ns]
#  6   Died2       8 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 576.0+ bytes

# %%
df['days']=df['Died2']-df['Born2']
df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#        Born2      Died2       days
# 0 1920-07-25 1958-04-16 13779 days
# 1 1876-06-13 1937-10-16 22404 days
# 2 1820-05-12 1910-08-13 32964 days
# 3 1867-11-07 1934-07-04 24345 days
# 4 1907-05-27 1964-04-14 20777 days
# 5 1813-03-15 1858-06-16 16529 days
# 6 1912-06-23 1954-06-07 15324 days
# ...

# %%
result = df[['Name','Born2','Died2','Age','Occupation','days']]
result
# Out:
#                    Name      Born2      Died2  Age          Occupation  \
# 0     Rosaline Franklin 1920-07-25 1958-04-16   37             Chemist
# 1        William Gosset 1876-06-13 1937-10-16   61        Statistician
# 2  Florence Nightingale 1820-05-12 1910-08-13   90               Nurse
# 3           Marie Curie 1867-11-07 1934-07-04   66             Chemist
# 4         Rachel Carson 1907-05-27 1964-04-14   56           Biologist
# 5             John Snow 1813-03-15 1858-06-16   45           Physician
# 6           Alan Turing 1912-06-23 1954-06-07   41  Computer Scientist
# 7          Johann Gauss 1777-04-30 1855-02-23   77       Mathematician
#
#         days
# 0 13779 days
# 1 22404 days
# 2 32964 days
# 3 24345 days
# 4 20777 days
# 5 16529 days
# 6 15324 days
# 7 28422 days

# %%
result.to_pickle('my_data.pickle') #용량 작고, 속도 빠름

# %%
data= pd.read_pickle('my_data.pickle')
data
# Out:
#                    Name      Born2      Died2  Age          Occupation  \
# 0     Rosaline Franklin 1920-07-25 1958-04-16   37             Chemist
# 1        William Gosset 1876-06-13 1937-10-16   61        Statistician
# 2  Florence Nightingale 1820-05-12 1910-08-13   90               Nurse
# 3           Marie Curie 1867-11-07 1934-07-04   66             Chemist
# 4         Rachel Carson 1907-05-27 1964-04-14   56           Biologist
# 5             John Snow 1813-03-15 1858-06-16   45           Physician
# 6           Alan Turing 1912-06-23 1954-06-07   41  Computer Scientist
# 7          Johann Gauss 1777-04-30 1855-02-23   77       Mathematician
#
#         days
# 0 13779 days
# 1 22404 days
# 2 32964 days
# 3 24345 days
# 4 20777 days
# 5 16529 days
# 6 15324 days
# 7 28422 days

# %%
import seaborn as sns # seaborn 데이터분석연습용 라이브러리(연습용 데이터) + 가시화 툴
import matplotlib.pyplot as pit # 그래프 가시화 툴

anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
data1 = anscombe[anscombe['dataset']=='I']
data2 = anscombe[anscombe['dataset']=='II']
data3 = anscombe[anscombe['dataset']=='III']
data4 = anscombe[anscombe['dataset']=='IV']

# %%
print(data1.mean())
print(data2.mean())
print(data3.mean())
print(data4.mean())
# Out:
# x    9.000000
# y    7.500909
# dtype: float64
# x    9.000000
# y    7.500909
# dtype: float64
# x    9.0
# y    7.5
# dtype: float64
# x    9.000000
# y    7.500909
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# ...

# %%
print(data1.std())
print(data2.std())
print(data3.std())
print(data4.std())
# Out:
# x    3.316625
# y    2.031568
# dtype: float64
# x    3.316625
# y    2.031657
# dtype: float64
# x    3.316625
# y    2.030424
# dtype: float64
# x    3.316625
# y    2.030579
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# ...

# %%
fig = pit.figure() # 흰색 도화지
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)

# %%
ax1.scatter(data1['x'],data1['y']) #산점도
ax2.scatter(data2['x'],data2['y'])
ax3.scatter(data3['x'],data3['y'])
ax4.scatter(data4['x'],data4['y'])
fig

# %%
ax1.plot(data1['x'],data1['y']) #선그래프
ax2.plot(data2['x'],data2['y'])
ax3.plot(data3['x'],data3['y'])
ax4.plot(data4['x'],data4['y'])
fig

# %%
ax1.set_title('Data1')
ax2.set_title('Data2')
ax3.set_title('Data3')
ax4.set_title('Data4')
fig

# %%
 fig.suptitle("Anscombe Data")
 fig

# %%
fig.tight_layout()
fig

# %%
tips =sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = pit.figure()
ax1 = fig.add_subplot(1,1,1)
fig

# %%
ax1.hist(tips['total_bill'],bins =10)
ax1.set_title("HISTOGRAM")
ax1.set_xlabel('Total Bill')
ax1.set_ylabel('FREQ')
fig

# %%
pit.scatter(tips['total_bill'],tips['tip'])

# %%
# matplotlib : 그래프
# seaborn : 자동으로 예쁘게
#pandas : 

sns.countplot('day',data=tips)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, fit_reg=False)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
sns.barplot(x='time',y='total_bill',data=tips)

# %%
sns.boxplot(x='time',y='total_bill',data=tips)

# %%
sns.violinplot(x='time',y='total_bill',data=tips)

# %%
sns.pairplot(tips,hue ='sex')

# %%
sns.lmplot(x='x',
           y='y',
           data=anscombe,
           fit_reg=False,
           col = 'dataset',
           col_wrap=2)# 2열로 표현

# %%
facet = sns.FacetGrid(tips, col ='time',hue='sex',row='smoker') # 집단별로 가시화
facet.map(pit.scatter,'total_bill','tip')

# %%
#panas

tips[['total_bill','tip']].plot.hist(alpha=0.5,bins = 20) #alpha = 투명도 bins 막대 수

# %%
tips['tip'].plot.kde() #밀도함수

# %%
tips.plot.scatter(x='total_bill',y='tip')

# %%
tips.plot.hexbin(x='total_bill',y='tip',gridsize=10)

# %%
tips.plot.box()

# %%
df1=pd.read_csv("concat_1.csv")
df2=pd.read_csv("concat_2.csv")
df3=pd.read_csv("concat_3.csv")

# %%
df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
df2
# Out:
#     A   B   C   D
# 0  a4  b4  c4  d4
# 1  a5  b5  c5  d5
# 2  a6  b6  c6  d6
# 3  a7  b7  c7  d7

# %%
df3
# Out:
#      A    B    C    D
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
pd.concat([df1,df2,df3])
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
a=pd.concat([df1,df2,df3],ignore_index=True)
a
# Out:
#       A    B    C    D
# 0    a0   b0   c0   d0
# 1    a1   b1   c1   d1
# 2    a2   b2   c2   d2
# 3    a3   b3   c3   d3
# 4    a4   b4   c4   d4
# 5    a5   b5   c5   d5
# 6    a6   b6   c6   d6
# 7    a7   b7   c7   d7
# 8    a8   b8   c8   d8
# 9    a9   b9   c9   d9
# 10  a10  b10  c10  d10
# 11  a11  b11  c11  d11

# %%
df2.columns = ['A','C','E','F']
df2
# Out:
#     A   C   E   F
# 0  a4  b4  c4  d4
# 1  a5  b5  c5  d5
# 2  a6  b6  c6  d6
# 3  a7  b7  c7  d7

# %%
pd.concat([df1,df2,df3]) #ef를 만들고 빈칸은 NaN
# Out:
#      A    B    C    D    E    F
# 0   a0   b0   c0   d0  NaN  NaN
# 1   a1   b1   c1   d1  NaN  NaN
# 2   a2   b2   c2   d2  NaN  NaN
# 3   a3   b3   c3   d3  NaN  NaN
# 0   a4  NaN   b4  NaN   c4   d4
# 1   a5  NaN   b5  NaN   c5   d5
# 2   a6  NaN   b6  NaN   c6   d6
# 3   a7  NaN   b7  NaN   c7   d7
# 0   a8   b8   c8   d8  NaN  NaN
# 1   a9   b9   c9   d9  NaN  NaN
# 2  a10  b10  c10  d10  NaN  NaN
# 3  a11  b11  c11  d11  NaN  NaN

# %%
a=pd.concat([df1,df2,df3],axis =1) # axis = 0일 경우 가로 기준 합침 (기본값)

# %%
a['A'] A값이 3개
# Out:
#     A   A    A
# 0  a0  a4   a8
# 1  a1  a5   a9
# 2  a2  a6  a10
# 3  a3  a7  a11

# %%
person=pd.read_csv('survey_person.csv')
site=pd.read_csv('survey_site.csv')
survey=pd.read_csv('survey_survey.csv')
visited=pd.read_csv('survey_visited.csv')

# %%
person
# Out:
#       ident   personal    family
# 0      dyer    William      Dyer
# 1        pb      Frank   Pabodie
# 2      lake   Anderson      Lake
# 3       roe  Valentina   Roerich
# 4  danforth      Frank  Danforth

# %%
site
# Out:
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40

# %%
survey
# Out:
#     taken person quant  reading
# 0     619   dyer   rad     9.82
# 1     619   dyer   sal     0.13
# 2     622   dyer   rad     7.80
# 3     622   dyer   sal     0.09
# 4     734     pb   rad     8.41
# 5     734   lake   sal     0.05
# 6     734     pb  temp   -21.50
# 7     735     pb   rad     7.22
# 8     735    NaN   sal     0.06
# 9     735    NaN  temp   -26.00
# 10    751     pb   rad     4.35
# 11    751     pb  temp   -18.50
# 12    751   lake   sal     0.10
# 13    752   lake   rad     2.19
# 14    752   lake   sal     0.09
# 15    752   lake  temp   -16.00
# 16    752    roe   sal    41.60
# 17    837   lake   rad     1.46
# 18    837   lake   sal     0.21
# 19    837    roe   sal    22.50
# 20    844    roe   rad    11.25

# %%
visited
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 1    622   DR-1  1927-02-10
# 2    734   DR-3  1939-01-07
# 3    735   DR-3  1930-01-12
# 4    751   DR-3  1930-02-26
# 5    752   DR-3         NaN
# 6    837  MSK-4  1932-01-14
# 7    844   DR-1  1932-03-22

# %%
a=visited.merge(site,left_on='site',right_on='name') #left_on에 기준이되는 열 적기 merge를 호추하는 객체 visited

# %%
del a['name']
a
# Out:
#    ident   site       dated    lat    long
# 0    619   DR-1  1927-02-08 -49.85 -128.57
# 1    622   DR-1  1927-02-10 -49.85 -128.57
# 2    844   DR-1  1932-03-22 -49.85 -128.57
# 3    734   DR-3  1939-01-07 -47.15 -126.72
# 4    735   DR-3  1930-01-12 -47.15 -126.72
# 5    751   DR-3  1930-02-26 -47.15 -126.72
# 6    752   DR-3         NaN -47.15 -126.72
# 7    837  MSK-4  1932-01-14 -48.87 -123.40

# %%
a=survey.merge(person,left_on='person',right_on='ident')
del a['ident']
a
# Out:
#     taken person quant  reading   personal   family
# 0     619   dyer   rad     9.82    William     Dyer
# 1     619   dyer   sal     0.13    William     Dyer
# 2     622   dyer   rad     7.80    William     Dyer
# 3     622   dyer   sal     0.09    William     Dyer
# 4     734     pb   rad     8.41      Frank  Pabodie
# 5     734     pb  temp   -21.50      Frank  Pabodie
# 6     735     pb   rad     7.22      Frank  Pabodie
# 7     751     pb   rad     4.35      Frank  Pabodie
# 8     751     pb  temp   -18.50      Frank  Pabodie
# 9     734   lake   sal     0.05   Anderson     Lake
# 10    751   lake   sal     0.10   Anderson     Lake
# 11    752   lake   rad     2.19   Anderson     Lake
# 12    752   lake   sal     0.09   Anderson     Lake
# 13    752   lake  temp   -16.00   Anderson     Lake
# 14    837   lake   rad     1.46   Anderson     Lake
# 15    837   lake   sal     0.21   Anderson     Lake
# 16    752    roe   sal    41.60  Valentina  Roerich
# ...

# %%
# 열이름이 같다면? survey.merge(person,on='person')

# %%
#누락값(결측치)
#결측치가 있을 때 연산에라

from numpy import NAN, nan, NaN

# %%
#for i in p:
 #   if i == nan: 불가!!
NaN==NaN
# Out:
# False

# %%
pd.isnull(NaN)
# Out:
# True

# %%
ebola = pd.read_csv('country_timeseries.csv')
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola.fillna(ebola.mean()) #nan값을 매개변수로 채움
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289   2776.000000    2335.337349       10030.000000
# 1      1/4/2015  288   2775.000000    2335.337349        9780.000000
# 2      1/3/2015  287   2769.000000    8166.000000        9722.000000
# 3      1/2/2015  286    911.064516    8157.000000        2427.367816
# 4    12/31/2014  284   2730.000000    8115.000000        9633.000000
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5    103.000000       8.000000           6.000000
# 118   3/26/2014    4     86.000000    2335.337349        2427.367816
# ...

# %%
ebola.fillna(method='ffill') #front fill 앞의 값으로 채움
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286        2769.0         8157.0             9722.0
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            8.0                6.0
# 119   3/25/2014    3          86.0            8.0                6.0
# 120   3/24/2014    2          86.0            8.0                6.0
# 121   3/22/2014    0          49.0            8.0                6.0
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.fillna(method='bfill') #back fill 뒤의 값으로 채움
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0         8166.0            10030.0
# 1      1/4/2015  288        2775.0         8166.0             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286        2730.0         8157.0             9633.0
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0             20.0            1.0                 4.0          1.0
# ...

# %%
#앞뒤 평균
#앞
#뒤 -> 모두 실행시 모두 채움 채울 수 있음
ebola.interpolate() # 앞뒤평균으로 채우기
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286        2749.5         8157.0             9677.5
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            8.0                6.0
# 119   3/25/2014    3          86.0            8.0                6.0
# 120   3/24/2014    2          86.0            8.0                6.0
# 121   3/22/2014    0          49.0            8.0                6.0
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
# 열을 행으로 내리는 것
pew = pd.read_csv('pew.csv')
pew
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
pew2 = pd.melt(pew,id_vars='religion',var_name='income',value_name='count') #열을 행으로 religion은 고정
pew2
# Out:
#                   religion              income  count
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
billboard = pd.read_csv('billboard.csv')
billboard
# Out:
#      year            artist                    track  time date.entered  wk1  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08   81
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21   76
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15   57
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29   86
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01   85
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18   95
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02   99
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29   60
#
# ...

# %%
billboard2 = pd.melt(billboard,id_vars=['year','artist','track','time','date.entered'],var_name='week',value_name='rank') #열을 행으로 religion은 고정
billboard2
# Out:
#        year            artist                    track  time date.entered  \
# 0      2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1      2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2      2000      3 Doors Down               Kryptonite  3:53   2000-04-08
# 3      2000      3 Doors Down                    Loser  4:24   2000-10-21
# 4      2000          504 Boyz            Wobble Wobble  3:35   2000-04-15
# ...     ...               ...                      ...   ...          ...
# 24087  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29
# 24088  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01
# 24089  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18
# 24090  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02
# 24091  2000   matchbox twenty                     Bent  4:12   2000-04-29
#
#        week  rank
# 0       wk1  87.0
# 1       wk1  91.0
# 2       wk1  81.0
# ...

# %%
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola2 = pd.melt(ebola,id_vars=['Date','Day']) #열을 행으로 religion은 고정
ebola2
# Out:
#             Date  Day      variable   value
# 0       1/5/2015  289  Cases_Guinea  2776.0
# 1       1/4/2015  288  Cases_Guinea  2775.0
# 2       1/3/2015  287  Cases_Guinea  2769.0
# 3       1/2/2015  286  Cases_Guinea     NaN
# 4     12/31/2014  284  Cases_Guinea  2730.0
# ...          ...  ...           ...     ...
# 1947   3/27/2014    5   Deaths_Mali     NaN
# 1948   3/26/2014    4   Deaths_Mali     NaN
# 1949   3/25/2014    3   Deaths_Mali     NaN
# 1950   3/24/2014    2   Deaths_Mali     NaN
# 1951   3/22/2014    0   Deaths_Mali     NaN
#
# [1952 rows x 4 columns]

# %%
split_data = ebola2['variable'].str.split('_')

# %%
ebola2['State']=split_data.str.get(0)
ebola2['Country']=split_data.str.get(1)

ebola2
# Out:
#             Date  Day      variable   value   State Country
# 0       1/5/2015  289  Cases_Guinea  2776.0   Cases  Guinea
# 1       1/4/2015  288  Cases_Guinea  2775.0   Cases  Guinea
# 2       1/3/2015  287  Cases_Guinea  2769.0   Cases  Guinea
# 3       1/2/2015  286  Cases_Guinea     NaN   Cases  Guinea
# 4     12/31/2014  284  Cases_Guinea  2730.0   Cases  Guinea
# ...          ...  ...           ...     ...     ...     ...
# 1947   3/27/2014    5   Deaths_Mali     NaN  Deaths    Mali
# 1948   3/26/2014    4   Deaths_Mali     NaN  Deaths    Mali
# 1949   3/25/2014    3   Deaths_Mali     NaN  Deaths    Mali
# 1950   3/24/2014    2   Deaths_Mali     NaN  Deaths    Mali
# 1951   3/22/2014    0   Deaths_Mali     NaN  Deaths    Mali
#
# [1952 rows x 6 columns]

# %%
del ebola2['variable']
ebola2
# Out:
#             Date  Day   value   State Country
# 0       1/5/2015  289  2776.0   Cases  Guinea
# 1       1/4/2015  288  2775.0   Cases  Guinea
# 2       1/3/2015  287  2769.0   Cases  Guinea
# 3       1/2/2015  286     NaN   Cases  Guinea
# 4     12/31/2014  284  2730.0   Cases  Guinea
# ...          ...  ...     ...     ...     ...
# 1947   3/27/2014    5     NaN  Deaths    Mali
# 1948   3/26/2014    4     NaN  Deaths    Mali
# 1949   3/25/2014    3     NaN  Deaths    Mali
# 1950   3/24/2014    2     NaN  Deaths    Mali
# 1951   3/22/2014    0     NaN  Deaths    Mali
#
# [1952 rows x 5 columns]

# %%
ebola2 = ebola2[['Date','Country','State','value']]
ebola2
# Out:
#             Date Country   State   value
# 0       1/5/2015  Guinea   Cases  2776.0
# 1       1/4/2015  Guinea   Cases  2775.0
# 2       1/3/2015  Guinea   Cases  2769.0
# 3       1/2/2015  Guinea   Cases     NaN
# 4     12/31/2014  Guinea   Cases  2730.0
# ...          ...     ...     ...     ...
# 1947   3/27/2014    Mali  Deaths     NaN
# 1948   3/26/2014    Mali  Deaths     NaN
# 1949   3/25/2014    Mali  Deaths     NaN
# 1950   3/24/2014    Mali  Deaths     NaN
# 1951   3/22/2014    Mali  Deaths     NaN
#
# [1952 rows x 4 columns]

# %%
split_data = ebola2['Date'].str.split('/')

# %%
ebola2['day']=split_data.str.get(0)
ebola2
# Out:
#             Date Country   State   value  yaer  year month day
# 0       1/5/2015  Guinea   Cases  2776.0   NaN  2015     5   1
# 1       1/4/2015  Guinea   Cases  2775.0   NaN  2015     4   1
# 2       1/3/2015  Guinea   Cases  2769.0   NaN  2015     3   1
# 3       1/2/2015  Guinea   Cases     NaN   NaN  2015     2   1
# 4     12/31/2014  Guinea   Cases  2730.0   NaN  2014    31  12
# ...          ...     ...     ...     ...   ...   ...   ...  ..
# 1947   3/27/2014    Mali  Deaths     NaN   NaN  2014    27   3
# 1948   3/26/2014    Mali  Deaths     NaN   NaN  2014    26   3
# 1949   3/25/2014    Mali  Deaths     NaN   NaN  2014    25   3
# 1950   3/24/2014    Mali  Deaths     NaN   NaN  2014    24   3
# 1951   3/22/2014    Mali  Deaths     NaN   NaN  2014    22   3
#
# [1952 rows x 8 columns]

# %%
ebola2=ebola2[['year','month','day','Country','State','value']]
# Out:
#       year month day Country   State   value
# 0     2015     5   1  Guinea   Cases  2776.0
# 1     2015     4   1  Guinea   Cases  2775.0
# 2     2015     3   1  Guinea   Cases  2769.0
# 3     2015     2   1  Guinea   Cases     NaN
# 4     2014    31  12  Guinea   Cases  2730.0
# ...    ...   ...  ..     ...     ...     ...
# 1947  2014    27   3    Mali  Deaths     NaN
# 1948  2014    26   3    Mali  Deaths     NaN
# 1949  2014    25   3    Mali  Deaths     NaN
# 1950  2014    24   3    Mali  Deaths     NaN
# 1951  2014    22   3    Mali  Deaths     NaN
#
# [1952 rows x 6 columns]

# %%
# ebola_split= ebola2['Date'].str.split('/',expand=True)
# ebola_split.columns=['Month','Day','Year']
# ebola3 = pd.concat([ebola2,ebola_split,axis=1])
# ebola3 다른 합치는 방법

weather = pd.read_csv('weather.csv')
weather
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
weather2 = pd.melt(weather, id_vars=['id','year','month','element'],var_name='Day',value_name='temp')
weather2
# Out:
#           id  year  month element  Day  temp
# 0    MX17004  2010      1    tmax   d1   NaN
# 1    MX17004  2010      1    tmin   d1   NaN
# 2    MX17004  2010      2    tmax   d1   NaN
# 3    MX17004  2010      2    tmin   d1   NaN
# 4    MX17004  2010      3    tmax   d1   NaN
# ..       ...   ...    ...     ...  ...   ...
# 677  MX17004  2010     10    tmin  d31   NaN
# 678  MX17004  2010     11    tmax  d31   NaN
# 679  MX17004  2010     11    tmin  d31   NaN
# 680  MX17004  2010     12    tmax  d31   NaN
# 681  MX17004  2010     12    tmin  d31   NaN
#
# [682 rows x 6 columns]

# %%
#행을 열로
weather3 = weather2.pivot_table(index = ['id','year','month','Day'], columns = 'element', values='temp', dropna=True) 
weather3
# Out:
# element                 tmax  tmin
# id      year month Day
# MX17004 2010 1     d30  27.8  14.5
#              2     d11  29.7  13.4
#                    d2   27.3  14.4
#                    d23  29.9  10.7
#                    d3   24.1  14.4
#              3     d10  34.5  16.8
#                    d16  31.1  17.6
#                    d5   32.1  14.2
#              4     d27  36.3  16.7
#              5     d27  33.2  18.2
#              6     d17  28.0  17.5
#                    d29  30.1  18.0
#              7     d3   28.6  17.5
#                    d14  29.9  16.5
#              8     d23  26.4  15.0
#                    d5   29.6  15.8
#                    d29  28.0  15.3
#                    d13  29.8  16.5
#                    d25  29.7  15.6
#                    d31  25.4  15.4
#                    d8   29.0  17.3
#              10    d5   27.0  14.0
#                    d14  29.5  13.0
#                    d15  28.7  10.5
#                    d28  31.2  15.0
# ...

# %%
weather3.reset_index()
# Out:
# element       id  year  month  Day  tmax  tmin
# 0        MX17004  2010      1  d30  27.8  14.5
# 1        MX17004  2010      2  d11  29.7  13.4
# 2        MX17004  2010      2   d2  27.3  14.4
# 3        MX17004  2010      2  d23  29.9  10.7
# 4        MX17004  2010      2   d3  24.1  14.4
# 5        MX17004  2010      3  d10  34.5  16.8
# 6        MX17004  2010      3  d16  31.1  17.6
# 7        MX17004  2010      3   d5  32.1  14.2
# 8        MX17004  2010      4  d27  36.3  16.7
# 9        MX17004  2010      5  d27  33.2  18.2
# 10       MX17004  2010      6  d17  28.0  17.5
# 11       MX17004  2010      6  d29  30.1  18.0
# 12       MX17004  2010      7   d3  28.6  17.5
# 13       MX17004  2010      7  d14  29.9  16.5
# 14       MX17004  2010      8  d23  26.4  15.0
# 15       MX17004  2010      8   d5  29.6  15.8
# 16       MX17004  2010      8  d29  28.0  15.3
# 17       MX17004  2010      8  d13  29.8  16.5
# 18       MX17004  2010      8  d25  29.7  15.6
# ...

# %%
billboard3 = billboard2[['year','artist','track','time']]
# Out:
#        year        artist  track  time
# 3      2000  3 Doors Down  Loser  4:24
# 320    2000  3 Doors Down  Loser  4:24
# 637    2000  3 Doors Down  Loser  4:24
# 954    2000  3 Doors Down  Loser  4:24
# 1271   2000  3 Doors Down  Loser  4:24
# ...     ...           ...    ...   ...
# 22510  2000  3 Doors Down  Loser  4:24
# 22827  2000  3 Doors Down  Loser  4:24
# 23144  2000  3 Doors Down  Loser  4:24
# 23461  2000  3 Doors Down  Loser  4:24
# 23778  2000  3 Doors Down  Loser  4:24
#
# [76 rows x 4 columns]

# %%
billboard3.drop_duplicates()
# Out:
#      year            artist                    track  time
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15
# 2    2000      3 Doors Down               Kryptonite  3:53
# 3    2000      3 Doors Down                    Loser  4:24
# 4    2000          504 Boyz            Wobble Wobble  3:35
# ..    ...               ...                      ...   ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19
# 315  2000     Zombie Nation            Kernkraft 400  3:30
# 316  2000   matchbox twenty                     Bent  4:12
#
# [317 rows x 4 columns]
